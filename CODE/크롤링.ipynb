# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install selenium webdriver_manager
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import time
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import csv
import re


service = Service(ChromeDriverManager().install())
d = webdriver.Chrome(service = service)

try:
    d.get("https://www.melon.com/index.htm")
    time.sleep(3)

    chart = d.find_element(By.CSS_SELECTOR, ".nth1") #멜론차트 클릭하기
    ac = ActionChains(d)
    ac.move_to_element(chart)
    ac.click()
    ac.pause(3) #기다리기
    ac.perform()
    
    finder = d.find_element(By.CSS_SELECTOR, ".chart_finder") #차트 파인더 클릭하기
    ac.reset_actions() #액션을 리셋
    ac.move_to_element(finder)
    ac.click()
    ac.pause(3) #기다리기
    ac.perform()

    finder_year = d.find_element(By.CSS_SELECTOR, ".tab03") #연도차트 클릭하기
    ac.reset_actions() #액션을 리셋
    ac.move_to_element(finder_year)
    ac.click()
    ac.pause(3) #기다리기
    ac.perform()

    years = d.find_elements(By.CSS_SELECTOR, ".list_value> ul > li") #연대 선택 클릭하기
    ac.reset_actions() #액션을 리셋
    ac.move_to_element(years[0])
    ac.click()
    ac.pause(3) #기다리기
    ac.perform()

    year = d.find_elements(By.CSS_SELECTOR, ".box_chic.nth2> .list_value> ul > li") #연도선택 클릭하기
    ac.reset_actions() #액션을 리셋
    ac.move_to_element(year[0])
    ac.click()
    ac.pause(3) #기다리기
    ac.perform()

    style = d.find_elements(By.CSS_SELECTOR, ".box_chic.last> .list_value> ul > li") #장르선태 클릭하기
    ac.reset_actions() #액션을 리셋
    ac.move_to_element(style[1])
    ac.click()
    ac.pause(3) #기다리기
    ac.perform()

    click = d.find_element(By.CSS_SELECTOR, ".btn_b26") #검색 클릭하기
    ac.reset_actions() #액션을 리셋
    ac.move_to_element(click)
    ac.click()
    ac.pause(10) #기다리기
    ac.perform()

    trs = d.find_elements(By.CSS_SELECTOR, "#chartListObj .lst50") #1-50
    for tr in trs:
        rank = tr.find_element(By.CSS_SELECTOR, ".right_none > span").text.strip()
        print(rank)  
        song_name = tr.find_element(By.CSS_SELECTOR, "#chartListObj > tr .rank01").text.strip()
        print(song_name)  
        artist = tr.find_element(By.CSS_SELECTOR, ".rank02 a").text.strip()
        print(artist) 
        likes = tr.find_element(By.CSS_SELECTOR, ".t_left .cnt").text.strip()
        print(likes)
        # 앨범사진 속성값 가져오기
        image = tr.find_element(By.CSS_SELECTOR, ".bg_album_frame")
        image2 = image.get_attribute("onclick")
        match = re.search(r"\d+", image2)
        extracted_value = match.group()
        print("앨범:", extracted_value)
        #가사 속성값 가져오기
        text = tr.find_element(By.CSS_SELECTOR, "button.btn_icon.add")
        text2 = text.get_attribute("onclick")
        match2 = re.search(r"(\d+)", text2)
        extracted_value = match2.group()
        print("가사:", extracted_value)
        
    next = d.find_element(By.CSS_SELECTOR, ".page_num a") #51-100위
    ac.reset_actions() #액션을 리셋
    ac.move_to_element(next)
    ac.click()
    ac.pause(5) #기다리기
    ac.perform()    

    trs2 = d.find_elements(By.CSS_SELECTOR, "#chartListObj .lst100") #51-100
    for tr2 in trs2:
        rank = tr2.find_element(By.CSS_SELECTOR, ".right_none > span").text.strip()
        print(rank)  
        song_name = tr2.find_element(By.CSS_SELECTOR, "#chartListObj > tr .rank01").text.strip()
        print(song_name)  
        artist = tr2.find_element(By.CSS_SELECTOR, ".rank02 a").text.strip()
        print(artist) 
        likes = tr2.find_element(By.CSS_SELECTOR, ".t_left .cnt").text.strip()
        print(likes) 
        #앨범 속성값
        image = tr2.find_element(By.CSS_SELECTOR, ".bg_album_frame")
        image2 = image.get_attribute("onclick")
        match3 = re.search(r"\d+", image2)
        extracted_value = match3.group()
        print("앨범:", extracted_value)
        #가사 속성값
        text = tr.find_element(By.CSS_SELECTOR, "button.btn_icon.add")
        text2 = text.get_attribute("onclick")
        match2 = re.search(r"(\d+)", text2)
        extracted_value = match2.group()
        print("가사:", extracted_value)   



except Exception as e:
    print(e)

finally:
    d.close()
    d.quit()
# Out:
# 1
# LOVE DIVE
# IVE (아이브)
# 242,793
# 앨범: 10909179
# 가사: 34847378
# 2
# TOMBOY
# (여자)아이들
# 241,398
# 앨범: 10890384
# 가사: 34754292
# 3
# 취중고백
# 김민석 (멜로망스)
# 173,285
# 앨범: 10816959
# 가사: 34431086
# 4
# 사랑인가 봐
# 멜로망스
# 194,115
# 앨범: 10871162
# 가사: 34657844
# 5
# 사랑은 늘 도망가
# 임영웅
# 202,910
# 앨범: 10735654
# 가사: 34061322
# 6
# ELEVEN
# IVE (아이브)
# 188,917
# 앨범: 10798794
# 가사: 34349913
# 7
# 봄여름가을겨울 (Still Life)
# BIGBANG (빅뱅)
# 299,163
# 앨범: 10908834
# 가사: 34845949
# 8
# 다정히 내 이름을 부르면
# 경서예지
# 177,698
# 앨범: 10610525
# 가사: 33496587
# 9
# That That (prod. & feat. SUGA of BTS)
# 싸이 (PSY)
# 136,124
# 앨범: 10937474
# 가사: 34997078
# 10
# 정이라고 하자 (Feat. 10CM)
# BIG Naughty (서동현)
# 216,844
# 앨범: 10925762
# 가사: 34927767
# 11
# 신호등
# 이무진
# 298,959
# 앨범: 10607796
# 가사: 33480898
# 12
# INVU
# 태연 (TAEYEON)
# 144,788
# 앨범: 10863559
# 가사: 34626109
# 13
# 회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)
# sokodomo
# 223,820
# 앨범: 10775252
# 가사: 34256568
# 14
# Feel My Rhythm
# Red Velvet (레드벨벳)
# 152,541
# ...

# %%
    title = driver.find_element_by_tag_name("h1").text

    # 추출한 데이터를 CSV 파일에 저장
    csv_filename = "data.csv"
    with open(csv_filename, mode='w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(["Title"])  # CSV 파일의 헤더 작성
    writer.writerow([title]) 
    title = driver.find_element_by_tag_name("h1").text
# Out:
#   Cell In[30], line 6
#     writer = csv.writer(csv_file)
#     ^
# IndentationError: expected an indented block after 'with' statement on line 5
